# %% [markdown]
# **LGMVIPJUNE**
#
# **LetsGrowMore TASK 3**
#
# **Data Science Intern June 2022**
#
# **TASK 3: Image to Pencil Sketch with Python**
#
# **Author:** Pushkar Zend

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
from IPython.display import Image
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import cv2

# %%
image = cv2.imread('/content/drive/MyDrive/content/drive/flower-color.jpg')

# %%
from google.colab.patches import cv2_imshow

# %%
photo = cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1564 at 0x7F76C603C210>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
inverted = 255-gray_image

# %%
blur = cv2.GaussianBlur(inverted, (21, 21), 0)

# %%
invertedblur = 255-blur

# %%
sketch = cv2.divide(gray_image, invertedblur, scale=256.0)

# %%
cv2.imwrite("outputImage.png", sketch)
# Out:
# True

# %%
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=L size=1600x1564 at 0x7F76C5761E50>

# %%
cv2.waitKey(0)
# Out:
# -1

# %%
image = cv2.imread('/content/drive/MyDrive/content/drive/flower-color.jpg',0)

# %%
photo = cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=1600x1564 at 0x7F76C57C2B50>
